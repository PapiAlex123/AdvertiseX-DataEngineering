# %%
import csv

def ingest_clicks_conversions(csv_data):
    reader = csv.DictReader(csv_data.splitlines())
    for row in reader:
        print("Ingested Click/Conversion:",row)

clicks_conversions_data = """event_timestamp,user_id,ad_campaign_id,conversion_type
2024-05-18T12:01:00Z,user_1,campaign_1,click
2024-05-18T12:02:00Z,user_2,campaign_1,conversion"""
ingest_clicks_conversions(clicks_conversions_data)
# Out:
# Ingested Click/Conversion: {'event_timestamp': '2024-05-18T12:01:00Z', 'user_id': 'user_1', 'ad_campaign_id': 'campaign_1', 'conversion_type': 'click'}
# Ingested Click/Conversion: {'event_timestamp': '2024-05-18T12:02:00Z', 'user_id': 'user_2', 'ad_campaign_id': 'campaign_1', 'conversion_type': 'conversion'}
